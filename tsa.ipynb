# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
# %pylab inline
df=pd.read_csv('tsa.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df[:5]
# Out:
#          item airport_code                                  airport_name  \
# 0    Firearms          BUR                      Burbank Bob Hope Airport
# 1  Ammunition          BWI  Baltimore / Washington International Airport
# 2  Ammunition          bwi  Baltimore / Washington International Airport
# 3    Firearms          CLT       Charlotte/Douglas International Airport
# 4  Ammunition          MDW                        Chicago Midway Airport
#
#           city state     date                 incident_type  \
# 0      Burbank    CA  10/1/14  Actual Dangerous/Deadly Item
# 1  BWI Airport    MD  10/1/14  Actual Dangerous/Deadly Item
# 2  BWI Airport    MD  10/1/14  Actual Dangerous/Deadly Item
# 3    Charlotte    NC  10/1/14  Actual Dangerous/Deadly Item
# 4      Chicago    IL  10/1/14  Actual Dangerous/Deadly Item
#
#                                     location
# 0  Passenger and Carry-on Screening Location
# 1  Passenger and Carry-on Screening Location
# ...

# %%
df.columns
# Out:
# Index([u'item', u'airport_code', u'airport_name', u'city', u'state', u'date',
#        u'incident_type', u'location'],
#       dtype='object')

# %%
df.describe()
# Out:
#                                   item airport_code  \
# count                            22196        22196
# unique                              16          361
# top     Part of Firearms or Ammunition          DEN
# freq                              7713         1006
#
#                         airport_name    city  state      date  \
# count                          22196   22196  22196     22196
# unique                           351     334     54       364
# top     Denver International Airport  Dallas     TX  11/26/14
# freq                            1006    1111   2906        97
#
#                        incident_type  \
# count                          22196
# unique                             1
# top     Actual Dangerous/Deadly Item
# freq                           22196
#
#                                          location
# count                                       22196
# unique                                          2
# ...

# %%
air_count=df['airport_code'].value_counts()

# %%
air_count.plot()

# %%
air_count.hist(bins=10)

# %%
item_count=df['item'].value_counts()

# %%
item_count.plot()

# %%
#checking missing values
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# item             3
# airport_code     3
# airport_name     3
# city             3
# state            3
# date             3
# incident_type    3
# location         3
# dtype: int64

# %%
pl=air_count[:10].plot(kind='bar', rot=0)
plt.title('TSA: Top 10 Airports for Weapon Confiscation FY2015');

# %%
pl2=air_count.plot(kind='line', rot=0)
plt.title('TSA: Top Airports Confiscated Weapons FY2015');

# %%
pl3=item_count[:10].plot(kind='barh', rot=0)
plt.title('TSA: Confiscated Weapons FY2015');
pl3.invert_yaxis()

# %%
df.groupby('item').airport_code.sum()
# Out:
# item
# Ammunition                                                  BWIbwiMDWPHXTPATYRATLCLTDFWKTNOTZLAXBNARSTAEXC...
# BB/Paint/Flare/Spear/Pellet Guns                            SFODENFATDTWMSNLAXSTLSLCRDUOAJLGAPHXPITLAXMIAO...
# Bio/Chem/Radio Agent                                                                                   SEAGEG
# Bludgeoning                                                 ORDGTFLAXLAXMSYOMARDUSFOSJCTULBOSMDWCMHFATOMAM...
# Cutting ltems (knives. razors, box cutters, saber, etc )    LAXJFKPWMSLCSATBOSCLEDTWBNAPHLPHLPHXPDXICTICTI...
# Explosive Device                                            BOSMIABOSSANSFOTUSSAVELPBZNPITMSPSANLASKOAMSPF...
# Firearms                                                    BURCLTDFWDENDENOAJOAKPHLSATAMAATLORDDFWDENDTWF...
# Fireworks                                                   KOABTVTUSIADFAYMIADENEUGBTVPHXBTVPITSEAJNUDENB...
# ...
